# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, OneHotEncoder, PolynomialFeatures, SplineTransformer, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate, cross_val_predict

from sklearn.feature_selection import SelectKBest, RFECV, SelectFromModel
from sklearn.feature_selection import f_classif, f_regression
from sklearn.decomposition import PCA
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import FunctionTransformer
from sklearn.neural_network import MLPClassifier

from statistics import median, mean


from imblearn.over_sampling import SMOTE

# %%
train_df = pd.read_csv('./smoking_train.csv')
test_df = pd.read_csv('./smoking_test.csv')

target = 'smoking'  
train_df = train_df.rename(columns={target: 'target'})

# %%
train_df.head()
# Out:
#    ID gender   age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   2      M  55.0         170        60.0       80.0             0.8
# 1   3      M  40.0         165        70.0       88.0             1.5
# 2   4      F  40.0         155        60.0       86.0             1.0
# 3   5      M  30.0         180        75.0       85.0             1.2
# 4   6      M  40.0         160        60.0       85.5             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              0.8            1.0             1.0  ...        15.8
# 1              1.5            1.0             1.0  ...        14.7
# 2              1.0            1.0             1.0  ...        12.5
# 3              1.2            1.0             1.0  ...        16.2
# 4              1.0            1.0             1.0  ...        17.0
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               1.0  21.0  16.0  22.0     Y              0
# 1            1.0               1.0  19.0  26.0  18.0     Y              0
# 2            1.0               0.6  16.0  14.0  22.0     Y              0
# 3            1.0               1.2  18.0  27.0  33.0     Y              0
# 4            1.0               0.7  21.0  27.0  39.0     Y              1
#
#    tartar  target
# 0       N     yes
# 1       Y      no
# 2       N      no
# 3       Y      no
# 4       Y     yes
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Отчистка и обработка данных

# %%
# посмотрим на корреляции между фичами

train_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/v8/1mw1z5052938mf5hp0437f_40000gn/T/ipykernel_39268/872815659.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   train_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_ec293_row0_col0, #T_ec293_row1_col1, #T_ec293_row2_col2, #T_ec293_row3_col3, #T_ec293_row4_col4, #T_ec293_row5_col5, #T_ec293_row6_col6, #T_ec293_row7_col7, #T_ec293_row8_col8, #T_ec293_row9_col9, #T_ec293_row10_col10, #T_ec293_row11_col11, #T_ec293_row12_col12, #T_ec293_row13_col13, #T_ec293_row14_col14, #T_ec293_row15_col15, #T_ec293_row16_col16, #T_ec293_row17_col17, #T_ec293_row18_col18, #T_ec293_row19_col19, #T_ec293_row20_col20, #T_ec293_row21_col21, #T_ec293_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ec293_row0_col1, #T_ec293_row3_col9, #T_ec293_row4_col20, #T_ec293_row15_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ec293_row0_col2, #T_ec293_row17_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ec293_row0_col3, #T_ec293_row1_col7, #T_ec293_row19_col14 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ec293_row0_col4, #T_ec293_row4_col21, #T_ec293_row7_col14 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ec293_row0_col5, #T_ec293_row10_col5, #T_ec293_row13_col6, #T_ec293_row15_col18, #T_ec293_row17_col5, #T_ec293_row20_col10, #T_ec293_row21_col5, #T_ec293_row22_col5, #T_ec293_row22_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ec293_row0_col6, #T_ec293_row18_col10, #T_ec293_row19_col5, #T_ec293_row19_col10, #T_ec293_row20_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ec293_row0_col7, #T_ec293_row0_col12, #T_ec293_row2_col19, #T_ec293_row13_col8, #T_ec293_row13_col15, #T_ec293_row18_col12, #T_ec293_row22_col12 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ec293_row0_
col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col10, #T_ec293_row1_col12, #T_ec293_row5_col20, #T_ec293_row6_col20, #T_ec293_row7_col5, #T_ec293_row12_col21, #T_ec293_row13_col22 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col13, #T_ec293_row5_col13, #T_ec293_row6_col13, #T_ec293_row13_col12, #T_ec293_row22_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ec293_row1_col14, #T_ec293_row2_col5, #T_ec293_row4_col11, #T_ec293_row7_col13, #T_ec293_row16_col10 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ec293_row1_col15, #T_ec293_row4_col8, #T_ec293_row6_col10, #T_ec293_row10_col15, #T_ec293_row15_col11, #T_ec293_row19_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col17, #T_ec293_row5_col15, #T_ec293_row7_col15, #T_ec293_row15_col21, #T_ec293_row16_col17 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col19, #T_ec293_row4_col17, #T_ec293_row5_col12, #T_ec293_row6_col12, #T_ec293_row12_col19 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col20, #T_ec293_row6_col21, #T_ec293_row7_col12, #T_ec293_row8_col12, #T_ec293_row8_col21, #T_ec293_row12_col7, #T_ec293_row20_col17, #T_ec293_row22_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ec293_row1_col21, #T_ec293_row5_col9, #T_ec293_row7_col21, #T_ec293_row9_col17, #T_ec293_row10_col17, #T_ec293_row14_col8, #T_ec293_row15_col7, #T_ec293_row15_col8, #T_ec293_row22_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ec293_row2_col3, #T_ec293_row20_col19 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_ec293_row2_col4, #T_ec293_row8_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_ec293_row2_col6, #T_ec293_row5_col16, #T_ec293_row8_col4, #T_ec293_row20_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ec293_row2_col9, #T_ec293_row8_col18, #T_ec293_row12_col5, #T_ec293_row14_col5, #T_ec293_row15_col5, #T_ec293_row16_col19, #T_ec293_row19_col9, #T_ec293_row21_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ec293_row2_col10, #T_ec293_row4_col5, #T_ec293_row4_col6, #T_ec293_row6_col18, #T_ec293_row9_col20 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ec293_row2_col11, #T_ec293_row8_col5, #T_ec293_row8_col9, #T_ec293_row9_col7, #T_ec293_row16_col14, #T_ec293_row17_col10, #T_ec293_row18_col22, #T_ec293_row20_col22 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ec293_row2_col13, #T_ec293_row10_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_ec293_row2_col14, #T_ec293_row13_col19, #T_ec293_row21_col22 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ec293_row2_col16 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ec293_row2_col18 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ec293_row2_col20, #T_ec293_row11_col10 {
#   backgrou

# %%
train_df.isna().sum(0)
# Out:
# ID                       0
# gender                   0
# age                    440
# height(cm)               0
# weight(kg)              44
# waist(cm)                0
# eyesight(left)           0
# eyesight(right)          0
# hearing(left)            0
# hearing(right)           0
# systolic                 0
# relaxation               0
# fasting blood sugar      0
# Cholesterol              0
# triglyceride             0
# HDL                      0
# LDL                      0
# hemoglobin               0
# Urine protein            0
# serum creatinine         0
# AST                      0
# ALT                      0
# Gtp                      0
# oral                     0
# dental caries            0
# tartar                   0
# target                   0
# dtype: int64

# %%
median_age = median(train_df['age'].dropna())
median_age
# Out:
# 40.0

# %%
median_weight = median(train_df['weight(kg)'].dropna())
median_weight
# Out:
# 65.0

# %%
train_df['age'] = train_df['age'].fillna(median_age)
test_df['age'] = test_df['age'].fillna(median_age)

train_df['weight(kg)'] = train_df['weight(kg)'].fillna(median_weight)
test_df['weight(kg)'] = train_df['weight(kg)'].fillna(median_weight)

# %%
train_df.nunique()
# Out:
# ID                     44554
# gender                     2
# age                       15
# height(cm)                13
# weight(kg)                23
# waist(cm)                548
# eyesight(left)            19
# eyesight(right)           17
# hearing(left)              2
# hearing(right)             2
# systolic                 127
# relaxation                94
# fasting blood sugar      270
# Cholesterol              278
# triglyceride             388
# HDL                      124
# LDL                      277
# hemoglobin               142
# Urine protein              6
# serum creatinine          37
# AST                      207
# ALT                      240
# Gtp                      464
# oral                       1
# dental caries              2
# tartar                     2
# target                     2
# dtype: int64

# %%
pd.concat([train_df,test_df]).nunique() - train_df.nunique()
# Out:
# ID                     11138
# gender                     0
# age                        0
# height(cm)                 0
# weight(kg)                 0
# waist(cm)                 18
# eyesight(left)             0
# eyesight(right)            0
# hearing(left)              0
# hearing(right)             0
# systolic                   3
# relaxation                 1
# fasting blood sugar        6
# Cholesterol                8
# triglyceride               2
# HDL                        2
# LDL                       12
# hemoglobin                 3
# Urine protein              0
# serum creatinine           1
# AST                       12
# ALT                        5
# Gtp                       24
# oral                       0
# dental caries              0
# tartar                     0
# target                     0
# dtype: int64

# %%
class ColumnDropperTransformer():
    def __init__(self,columns):
        self.columns=columns

    def transform(self,X,y=None):
        return X.drop(self.columns,axis=1)

    def fit(self, X, y=None):
        return self

# %%
cat_cols = [x for x in train_df.nunique()[train_df.nunique() < 25].index.to_list() if x != 'target']
num_cols = [column for column in train_df.columns if column not in cat_cols + ['target']]

cat_steps = [
    ('onehot', OneHotEncoder(handle_unknown='ignore',)),
]
num_steps = [
    ('dropper', ColumnDropperTransformer(['ID'])),
    ('scaler1', StandardScaler()),
    ('pwr', PowerTransformer()),
    ('poly', PolynomialFeatures(3, include_bias=False)),
    ('scaler', StandardScaler()),
]

cat_transformer = Pipeline(cat_steps)
num_transformer = Pipeline(num_steps)
preprocessor = ColumnTransformer(
    [
        ('num',  num_transformer, num_cols),
        ('cat', cat_transformer, cat_cols)
    ]
)


model = LogisticRegression(max_iter= 2000, random_state=42)


pipe = Pipeline([
    ('prep', preprocessor),
    ('model', model)
])

# %%
enc = LabelEncoder()

X = train_df.drop('target', axis=1)
y = enc.fit_transform(train_df['target'])

# %%
X.head()

cv_oupt = cross_validate(pipe, X, y, cv=5, scoring='f1', return_estimator=True)
scores = cv_oupt['test_score']
models = cv_oupt['estimator']

# %%
scores.mean(), scores.std()
# Out:
# (0.6995487383388944, 0.03910482112434293)

# %%
preds = []
for model in models:
    pred = model.predict_proba(test_df)
    preds.append(pred)

# %%
preds = np.array(preds)

# %%
subm_preds = enc.inverse_transform(preds.mean(axis=0).argmax(axis=1))

# %%
subm_df = pd.DataFrame({'ID': test_df.ID, 'smoking': subm_preds})

# %%
subm_df
# Out:
#           ID smoking
# 0      48715     yes
# 1      49650     yes
# 2      18013      no
# 3      24282      no
# 4       9215      no
# ...      ...     ...
# 11133  20787     yes
# 11134   5000      no
# 11135  36617      no
# 11136  38229     yes
# 11137  48024      no
#
# [11138 rows x 2 columns]

# %%
subm_df.to_csv('subm.csv', index=False)
