# %% [markdown]
# ## Списки

# %% [markdown]
# Вам дан список. Создайте новый список, в котором порядок следования элементов будет обратным относительно исходного списка.

# %%
# ваше решение
x = [1, 2, 4, 6, 7]
y = x[-1::-1]
y
# Out:
# [7, 6, 4, 2, 1]

# %% [markdown]
# Вам дан список. Создайте новый список, в котором будут присутствовать только чётные элементы исходного списка.

# %%
# ваше решение
x = [1, 5, 3, 6, 8, 4]
y = [a for a in x if a % 2 == 0]
y
# Out:
# [6, 8, 4]

# %% [markdown]
# ## Генераторы

# %% [markdown]
# Вам дан список. Создайте новый список, который удвоит каждый элемент исходного списка.

# %%
# ваше решение
x = [8, 6, 32, 21]
y = [a * 2 for a in x]
y
# Out:
# [16, 12, 64, 42]

# %% [markdown]
# Вам дан список. Создайте новый список, который умножит увеличит на треть элемент исходного списка.

# %%
x = [2, 3, 5 , 6, 32, 43]
y = [a * (1/3) for a in x]
y
# Out:
# [0.6666666666666666,
#  1.0,
#  1.6666666666666665,
#  2.0,
#  10.666666666666666,
#  14.333333333333332]

# %% [markdown]
# ## Встроенные функции

# %% [markdown]
# Вам дана строка. Выведите ascii-код максимального элемента в строке.

# %%
# ваше решение
s = 'abacaba'
ans = max(s)
ord(ans)
# Out:
# 99

# %% [markdown]
# Вам дана строка. Преобразуйте её в кортежи, состоящие из пары – порядковый номер элемента строки, ascii-код элемента.

# %%
# ваше решение
s = 'abacaba'
ans = {i : ord(s[i]) for i in range(len(s))}
ans
# Out:
# {0: 97, 1: 98, 2: 97, 3: 99, 4: 97, 5: 98, 6: 97}

# %% [markdown]
# ## NumPy

# %% [markdown]
# Создайте многомерный массив, посчитайте суммы элементов по различным осям.

# %%
import numpy as np

# %%
# ваше решение
# Matrix = np.array([[np.random.randint(i) for i in range(1, 6)] for i in range(8)])
# ans1 = np.sum(Matrix, axis= 1)
# ans2 = np.sum(Matrix, axis= 0)
# ans1, ans2
shape = np.array(list(map(int, input().split())))

n = 1 # Колл-во элементов

for el in shape:
    n *= el


Matrix = np.arange(n).reshape(shape)

ax = int(input())

np.sum(Matrix, axis = ax)
# Out:
# array([[  6,  22,  38],
#        [ 54,  70,  86],
#        [102, 118, 134],
#        [150, 166, 182]])

# %% [markdown]
# Дан массив A (numpy.array()), заполненный 1.
# Дан массив I (numpy.array()) индексов.
#
# Прибавьте к каждому значению массиву A по массиву индексов +1.

# %%
import numpy as np

n = 10
k = 12
A = np.ones(n)
I = np.random.randint(0,len(A),k)

B = np.bincount(I)

A + B
# Out:
# array([4., 2., 2., 2., 2., 1., 2., 4., 1., 2.])

# %% [markdown]
# ## Pandas

# %% [markdown]
# https://www.kaggle.com/datasets/vinesmsuic/star-categorization-giants-and-dwarfs

# %% [markdown]
# - Какие типы данных присутствуют в датасете?
# - Есть ли в датасете пропущенные значения? Если да, то сколько и где?
# - Постройте гистаграмму переменной `Target`.
# - Постройте heatmap для матрицы корреляции переменных в датасете.
# - Постройте pairplot для всех переменных
# - Постройте boxplot для всех переменных и выведете объекты которые являются выбросами (строки из датафрейма).
# - Посчитайте различные статестические показатели (среднее, медиана, максимум, минимум) для различных классов *(т.е. отдельно какие показатели у класса 0, какие у класса 1)*.
# - Проанализируйте колонку `SpType`. Подсчитаете количество звёзд относящихся к различным классам.
# `SpType` - спектральный класс звезды согласно классификации Моргана-Кинана.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stardf = pd.read_csv('Star3642_balanced.csv')

# %%
stardf.dtypes
# Out:
# Vmag           float64
# Plx            float64
# e_Plx          float64
# B-V            float64
# SpType          object
# Amag           float64
# TargetClass      int64
# dtype: object

# %%
stardf.isnull().sum()
# Out:
# Vmag           0
# Plx            0
# e_Plx          0
# B-V            0
# SpType         0
# Amag           0
# TargetClass    0
# dtype: int64

# %%
sns.histplot(data=stardf, x="TargetClass");
plt.title("TargetClass Hist");

# %%
sns.heatmap(stardf.corr(), xticklabels=stardf.corr().columns, yticklabels=stardf.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('Correlogram of Star Dataset', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# /tmp/ipykernel_45749/3579500042.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(stardf.corr(), xticklabels=stardf.corr().columns, yticklabels=stardf.corr().columns, cmap='RdYlGn', center=0, annot=True)
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5]),
#  [Text(0, 0.5, 'Vmag'),
#   Text(0, 1.5, 'Plx'),
#   Text(0, 2.5, 'e_Plx'),
#   Text(0, 3.5, 'B-V'),
#   Text(0, 4.5, 'Amag'),
#   Text(0, 5.5, 'TargetClass')])

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(stardf, kind="reg")

# %%
# plt.figure(figsize=(100,80), dpi= 800)

# stardf[['Vmag', 'Plx', 'e_Plx', 'B-V', 'SpType', 'Amag', 'TargetClass']].plot(kind='box')


fig, axes = plt.subplots(2, 3)  

sns.boxplot(stardf['Vmag'], ax=axes[0][0], width=0.3)
hight1 = stardf['Vmag'].quantile(0.25)
low1 = stardf['Vmag'].quantile(0.75)
res1 = stardf[(stardf['Vmag'] < hight1) | (stardf['Vmag'] > low1)]
sns.boxplot(stardf['Plx'], ax=axes[0][1], width=0.3)
hight2 = stardf['Plx'].quantile(0.25)
low2 = stardf['Plx'].quantile(0.75)
res2 = stardf[(stardf['Plx'] < hight2) | (stardf['Plx'] > low2)]
sns.boxplot(stardf['e_Plx'], ax=axes[0][2], width=0.3)
hight3 = stardf['e_Plx'].quantile(0.25)
low3 = stardf['e_Plx'].quantile(0.75)
res3 = stardf[(stardf['e_Plx'] < hight3) | (stardf['e_Plx'] > low3)]
sns.boxplot(stardf['B-V'], ax=axes[1][0], width=0.3)
hight4 = stardf['B-V'].quantile(0.25)
low4 = stardf['B-V'].quantile(0.75)
res4 = stardf[(stardf['B-V'] < hight4) | (stardf['B-V'] > low4)]
# sns.boxplot(stardf['SpType'], ax=axes[1][1], widtSh=0.3)
sns.boxplot(stardf['Amag'], ax=axes[1][1], width=0.3)
hight5 = stardf['Amag'].quantile(0.25)
low5 = stardf['Amag'].quantile(0.75)
res5 = stardf[(stardf['Amag'] < hight5) | (stardf['Amag'] > low5)]
sns.boxplot(stardf['TargetClass'], ax=axes[1][2], width=0.3)
hight6 = stardf['TargetClass'].quantile(0.25)
low6 = stardf['TargetClass'].quantile(0.75)
res6 = stardf[(stardf['TargetClass'] < hight6) | (stardf['TargetClass'] > low6)]

# %%
# stardf.describe()

print(stardf.loc[stardf['TargetClass'] == 1].describe()) 
print(stardf.loc[stardf['TargetClass'] == 0].describe())
# Out:
#               Vmag          Plx        e_Plx          B-V         Amag  \
# count  1821.000000  1821.000000  1821.000000  1821.000000  1821.000000
# mean      8.474514    11.113926     1.328358     0.557915    17.834092
# std       1.303624    15.609759     1.075714     0.295059     1.961758
# min       0.450000    -6.820000     0.490000    -0.196000     4.140000
# 25%       7.880000     4.720000     0.920000     0.417000    16.797817
# 50%       8.750000     7.590000     1.150000     0.526000    17.947254
# 75%       9.340000    12.500000     1.410000     0.677000    18.903980
# max      12.490000   280.270000    30.290000     1.850000    29.249165
#
#        TargetClass
# count       1821.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0
#               Vmag          Plx        e_Plx          B-V         Amag  \
# count  1821.000000  1821.000000  1821.000000  1821.000000  1821.000000
# ...

# %% [markdown]
# Проанализируйте колонку `SpType`. Подсчитаете количество звёзд относящихся к различным классам.
# `SpType` - спектральный класс звезды согласно классификации Моргана-Кинана.

# %%
import re

tmp = r'[OABCFGKM]'


stardf['SpType_1'] = stardf['SpType'].apply(lambda x: re.findall(tmp, x))
stardf['SpType_1'] = stardf['SpType_1'].apply(lambda x: list(set(x)))

stardf['SpType_1'].value_counts()
# Out:
# [K]       1249
# [F]        858
# [G]        761
# [K, G]     472
# [K, C]     360
# [A]        236
# [B]        188
# [M]        187
# [F, G]     152
# [M, K]      64
# [C, G]      56
# [B, M]      40
# [F, A]      24
# [B, G]      24
# [B, K]      24
# [G, A]       8
# [K, F]       8
# [B, A]       8
# [M, C]       8
# [O]          5
# [C]          2
# Name: SpType_1, dtype: int64

# %%
stardf = stardf.explode('SpType_1')
stardf['SpType_1'].value_counts()
# Out:
# K    1713
# G    1117
# F     950
# A     256
# M     243
# B     236
# C     214
# O       5
# Name: SpType_1, dtype: int64
